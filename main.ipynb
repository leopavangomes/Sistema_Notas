# %%
from cadastrar import cadastrar_aluno
from calcular_media import calcular_media
from verificar import verificar_situacao

aluno = cadastrar_aluno()
media = calcular_media(aluno["nota1"], aluno["nota2"])
situacao = verificar_situacao(media)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from cadastrar import cadastrar_aluno
#       2 from calcular_media import calcular_media
# ----> 3 from verificar import verificar_situacao
#       5 aluno = cadastrar_aluno()
#       6 media = calcular_media(aluno["nota1"], aluno["nota2"])
#
# ImportError: cannot import name 'verificar_situacao' from 'verificar' (c:\Users\52625427\Documents\GitHub\Sistema_Notas\verificar.py)
